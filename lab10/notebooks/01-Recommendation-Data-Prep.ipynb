# %% [markdown]
# # Recommendation - Data Preparation 🎬

# %% [markdown]
# ---

# %% [markdown]
# <img src="https://cdn-images-1.medium.com/max/1200/0*ePGWILY6GyplT-nn" />

# %% [markdown]
# ---

# %% [markdown]
# In the next few challenges, you will build a powerful **movie recommender**.
#
# We will use the open-source library [LightFM](https://github.com/lyst/lightfm) which provides easy python implementation of **hybrid** recommendation engines.
#
# In this first part, we will prepare the data in order to train efficiently of the model.
#
# We let you load the data `movies` and `ratings` downloaded from the **small** [movielens dataset](https://grouplens.org/datasets/movielens/).

# %%
### TODO: Load the movies and ratings datasets
import pandas as pd
movies = pd.read_csv("ml-latest-small/movies.csv")
ratings = pd.read_csv("ml-latest-small/ratings.csv")

print(movies.head())
print(ratings.head())
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
pip install lightfm
# Out:
# Collecting lightfm
#   Downloading lightfm-1.16.tar.gz (310 kB)
#      |████████████████████████████████| 310 kB 73 kB/s eta 0:00:01
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.9/site-packages (from lightfm) (1.20.3)
# Requirement already satisfied: scipy>=0.17.0 in /opt/anaconda3/lib/python3.9/site-packages (from lightfm) (1.7.1)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.9/site-packages (from lightfm) (2.26.0)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.9/site-packages (from lightfm) (0.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from requests->lightfm) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests->lightfm) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests->lightfm) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from requests->lightfm) (2.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->lightfm) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->lightfm) (1.1.0)
# Building wheels for collected packages: lightfm
#   Building wheel for lightfm (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/anaconda3/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/5n/x_95j7x91xv3xxr2176lphzm0000gn/T/pip-install-9goepkrc/lightfm_546c7bb428dd4de9bec6d8807e78486b/setup.py'"'"'; __file__='"'"'/private/var/folders/5n/x_95j7x91xv3xxr2176lphzm0000gn/T/pip-install-9goepkrc/lightfm_546c7bb428dd4de9bec6d8807e78486b/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/5n/x_95j7x91xv3xxr2176lphzm0000gn/T/pip-wheel-xyrrp9el
#        cwd: /private/var/folders/5n/x_95j7x91xv3xxr2176lphzm0000gn/T/pip-install-9goepkrc/lightfm_546c7bb428dd4de9bec6d8807e78486b/
#   Complete output (29 lines):
#   Compiling without OpenMP support.
#   /opt/anaconda3/lib/python3.9/site-packages/setuptools/dist.py:717: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#     warnings.warn(
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.9-x86_64-3.9
#   creating build/lib.macosx-10.9-x86_64-3.9/lightfm
#   copying lightfm/lightfm.py -> build/lib.macosx-10.9-x86_64-3.9/lightfm
#   copying lightfm/evaluation.py -> build/lib.macosx-10.9-x86_64-3.9/lightfm
#   copying lightfm/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/lightfm
#   copying lightfm/_lightfm_fast.py -> build/lib.macosx-10.9-x86_64-3.9/lightfm
#   copying lightfm/data.py -> build/lib.macosx-10.9-x86_64-3.9/lightfm
#   copying lightfm/cross_validation.py -> build/lib.macosx-10.9-x86_64-3.9/lightfm
#   creating build/lib.macosx-10.9-x86_64-3.9/lightfm/datasets
#   copying lightfm/datasets/_common.py -> build/lib.macosx-10.9-x86_64-3.9/lightfm/datasets
#   copying lightfm/datasets/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/lightfm/datasets
#   copying lightfm/datasets/movielens.py -> build/lib.macosx-10.9-x86_64-3.9/lightfm/datasets
#   copying lightfm/datasets/stackexchange.py -> build/lib.macosx-10.9-x86_64-3.9/lightfm/datasets
#   copying lightfm/_lightfm_fast_no_openmp.c -> build/lib.macosx-10.9-x86_64-3.9/lightfm
#   copying lightfm/_lightfm_fast_openmp.c -> build/lib.macosx-10.9-x86_64-3.9/lightfm
#   running build_ext
#   building 'lightfm._lightfm_fast_no_openmp' extension
#   creating build/temp.macosx-10.9-x86_64-3.9
#   creating build/temp.macosx-10.9-x86_64-3.9/lightfm
#   clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/include -arch x86_64 -I/opt/anaconda3/include -fPIC -O2 -isystem /opt/anaconda3/include -arch x86_64 -I/opt/anaconda3/include/python3.9 -c lightfm/_lightfm_fast_no_openmp.c -o build/temp.macosx-10.9-x86_64-3.9/lightfm/_lightfm_fast_no_openmp.o -ffast-math -march=native
#   xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#   error: command '/usr/bin/clang' failed with exit code 1
#   ----------------------------------------
#   ERROR: Failed building wheel for lightfm
#   Running setup.py clean for lightfm
# Failed to build lightfm
# Installing collected packages: lightfm
#     Running setup.py install for lightfm ... error
#     ERROR: Command errored out with exit status 1:
#      command: /opt/anaconda3/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/5n/x_95j7x91xv3xxr2176lphzm0000gn/T/pip-install-9goepkrc/lightfm_546c7bb428dd4de9bec6d8807e78486b/setup.py'"'"'; __file__='"'"'/private/var/folders/5n/x_95j7x91xv3xxr2176lphzm0000gn/T/pip-install-9goepkrc/lightfm_546c7bb428dd4de9bec6d8807e78486b/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/5n/x_95j7x91xv3xxr2176lphzm0000gn/T/pip-record-pon2bncm/install-record.txt --single-version-externally-managed --compile --install-headers /opt/anaconda3/include/python3.9/lightfm
#          cwd: /private/var/folders/5n/x_95j7x91xv3xxr2176lphzm0000gn/T/pip-install-9goepkrc/lightfm_546c7bb428dd4de9bec6d8807e78486b/
#     Complete output (29 lines):
#     Compiling without OpenMP support.
#     /opt/anaconda3/lib/python3.9/site-packages/setuptools/dist.py:717: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#       warnings.warn(
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.9-x86_64-3.9
#     creating build/lib.macosx-10.9-x86_64-3.9/lightfm
#     copying lightfm/lightfm.py -> build/lib.macosx-10.9-x86_64-3.9/lightfm
#     copying lightfm/evaluation.py -> build/lib.macosx-10.9-x86_64-3.9/lightfm
#     copying lightfm/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/lightfm
#     copying lightfm/_lightfm_fast.py -> build/lib.macosx-10.9-x86_64-3.9/lightfm
#     copying lightfm/data.py -> build/lib.macosx-10.9-x86_64-3.9/lightfm
#     copying lightfm/cross_validation.py -> build/lib.macosx-10.9-x86_64-3.9/lightfm
#     creating build/lib.macosx-10.9-x86_64-3.9/lightfm/datasets
#     copying lightfm/datasets/_common.py -> build/lib.macosx-10.9-x86_64-3.9/lightfm/datasets
#     copying lightfm/datasets/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/lightfm/datasets
#     copying lightfm/datasets/movielens.py -> build/lib.macosx-10.9-x86_64-3.9/lightfm/datasets
#     copying lightfm/datasets/stackexchange.py -> build/lib.macosx-10.9-x86_64-3.9/lightfm/datasets
#     copying lightfm/_lightfm_fast_no_openmp.c -> build/lib.macosx-10.9-x86_64-3.9/lightfm
#     copying lightfm/_lightfm_fast_openmp.c -> build/lib.macosx-10.9-x86_64-3.9/lightfm
#     running build_ext
#     building 'lightfm._lightfm_fast_no_openmp' extension
#     creating build/temp.macosx-10.9-x86_64-3.9
#     creating build/temp.macosx-10.9-x86_64-3.9/lightfm
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/include -arch x86_64 -I/opt/anaconda3/include -fPIC -O2 -isystem /opt/anaconda3/include -arch x86_64 -I/opt/anaconda3/include/python3.9 -c lightfm/_lightfm_fast_no_openmp.c -o build/temp.macosx-10.9-x86_64-3.9/lightfm/_lightfm_fast_no_openmp.o -ffast-math -march=native
#     xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#     error: command '/usr/bin/clang' failed with exit code 1
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /opt/anaconda3/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/5n/x_95j7x91xv3xxr2176lphzm0000gn/T/pip-install-9goepkrc/lightfm_546c7bb428dd4de9bec6d8807e78486b/setup.py'"'"'; __file__='"'"'/private/var/folders/5n/x_95j7x91xv3xxr2176lphzm0000gn/T/pip-install-9goepkrc/lightfm_546c7bb428dd4de9bec6d8807e78486b/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/5n/x_95j7x91xv3xxr2176lphzm0000gn/T/pip-record-pon2bncm/install-record.txt --single-version-externally-managed --compile --install-headers /opt/anaconda3/include/python3.9/lightfm Check the logs for full command output.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **Q1**. What are the different types of recommendation models? Explain briefly with your own words the differences between them.

# %%
#user-based Weigh all users with respect to their similarity with the current  current user user.
#item-based Weigh all items with respect to their similarity with the current  current user item.

# %% [markdown]
# **Q1bis**. What data is expected by the LightFM `fit` method? Especially, how does the train data should be organized, and what should be the type of the train dataset?

# %%
#sparse matrix, using WARP to organize train data 
#all interactions in the training matrix are treated as positive signal

# %% [markdown]
# **Q2**. Explore `movies` and `ratings`, what do those datasets contain? How are they organized?

# %%
#foe example, userID1 gave the movieID1(Tor Story, 1995) rating 4.0, 
#and movieID47(Seven (a.k.a. Se7en) (1995)) rating 5.0

# %%
print(movies.shape)
movies.head(47)
# Out:
# (9742, 3)
#     movieId                                              title  \
# 0         1                                   Toy Story (1995)
# 1         2                                     Jumanji (1995)
# 2         3                            Grumpier Old Men (1995)
# 3         4                           Waiting to Exhale (1995)
# 4         5                 Father of the Bride Part II (1995)
# 5         6                                        Heat (1995)
# 6         7                                     Sabrina (1995)
# 7         8                                Tom and Huck (1995)
# 8         9                                Sudden Death (1995)
# 9        10                                   GoldenEye (1995)
# 10       11                     American President, The (1995)
# 11       12                 Dracula: Dead and Loving It (1995)
# 12       13                                       Balto (1995)
# 13       14                                       Nixon (1995)
# 14       15                            Cutthroat Island (1995)
# 15       16                                      Casino (1995)
# 16       17                       Sense and Sensibility (1995)
# 17       18                                  Four Rooms (1995)
# 18       19              Ace Ventura: When Nature Calls (1995)
# 19       20                                 Money Train (1995)
# 20       21                                  Get Shorty (1995)
# 21       22                                     Copycat (1995)
# 22       23                                   Assassins (1995)
# 23       24                                      Powder (1995)
# 24       25                           Leaving Las Vegas (1995)
# 25       26                                     Othello (1995)
# 26       27                                Now and Then (1995)
# 27       28                                  Persuasion (1995)
# 28       29  City of Lost Children, The (Cité des enfants p...
# 29       30  Shanghai Triad (Yao a yao yao dao waipo qiao) ...
# 30       31                             Dangerous Minds (1995)
# 31       32          Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 32       34                                        Babe (1995)
# 33       36                            Dead Man Walking (1995)
# 34       38                                It Takes Two (1995)
# 35       39                                    Clueless (1995)
# 36       40                    Cry, the Beloved Country (1995)
# 37       41                                 Richard III (1995)
# 38       42                             Dead Presidents (1995)
# 39       43                                 Restoration (1995)
# 40       44                               Mortal Kombat (1995)
# 41       45                                  To Die For (1995)
# 42       46               How to Make an American Quilt (1995)
# 43       47                        Seven (a.k.a. Se7en) (1995)
# 44       48                                  Pocahontas (1995)
# 45       49                       When Night Is Falling (1995)
# 46       50                         Usual Suspects, The (1995)
#
#                                          genres
# 0   Adventure|Animation|Children|Comedy|Fantasy
# 1                    Adventure|Children|Fantasy
# 2                                Comedy|Romance
# 3                          Comedy|Drama|Romance
# 4                                        Comedy
# 5                         Action|Crime|Thriller
# 6                                Comedy|Romance
# 7                            Adventure|Children
# 8                                        Action
# 9                     Action|Adventure|Thriller
# 10                         Comedy|Drama|Romance
# 11                                Comedy|Horror
# 12                 Adventure|Animation|Children
# 13                                        Drama
# 14                     Action|Adventure|Romance
# 15                                  Crime|Drama
# 16                                Drama|Romance
# 17                                       Comedy
# 18                                       Comedy
# 19           Action|Comedy|Crime|Drama|Thriller
# 20                        Comedy|Crime|Thriller
# 21          Crime|Drama|Horror|Mystery|Thriller
# 22                        Action|Crime|Thriller
# 23                                 Drama|Sci-Fi
# 24                                Drama|Romance
# 25                                        Drama
# 26                               Children|Drama
# 27                                Drama|Romance
# 28       Adventure|Drama|Fantasy|Mystery|Sci-Fi
# 29                                  Crime|Drama
# 30                                        Drama
# 31                      Mystery|Sci-Fi|Thriller
# 32                               Children|Drama
# 33                                  Crime|Drama
# 34                              Children|Comedy
# 35                               Comedy|Romance
# 36                                        Drama
# 37                                    Drama|War
# 38                           Action|Crime|Drama
# 39                                        Drama
# 40                     Action|Adventure|Fantasy
# 41                        Comedy|Drama|Thriller
# 42                                Drama|Romance
# 43                             Mystery|Thriller
# 44     Animation|Children|Drama|Musical|Romance
# 45                                Drama|Romance
# 46                       Crime|Mystery|Thriller

# %%
print(ratings.shape)
ratings.head()
# Out:
# (100836, 4)
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %% [markdown]
# ---

# %% [markdown]
# ### Q3 & Q4 are optional
# > you can come back to it if you have time after having finished the whole project of the day

# %% [markdown]
# We created a few utils functions for you in `utils.py` script. Especially:
# - `threshold_interactions_df`:
# > Limit interactions df to minimum row and column interactions
#
# **Q3**. Open `src/utils.py` file, and have a look at the documentation of this function to understand its goal and how it works.
#
# Have a look the code to understand fully how it works. You should be familiar with everything.
#
# What does represent the variable `sparsity`? What is the range of values in which sparsity can be?

# %% [markdown]
# **Q4**. Create a new DataFrame `ratings_thresh`, that filters `ratings` with only:
# - users that rated strictly more than 4 movies
# - movies that have been rated at least 10 times
#
# How many users/movies remain in this new dataset?

# %%
from utils import threshold_interactions_df

ratings_thresh_df = threshold_interactions_df(
    ratings, 
    'userId', 
    'movieId', 
    5,  
    10
)

print(len(ratings_thresh_df.userId.unique()), 
      len(ratings_thresh_df.movieId.unique())
)
# Out:
# Starting interactions info
# Number of rows: 610
# Number of cols: 9724
# Sparsity: 1.700%
# Ending interactions info
# Number of rows: 610
# Number of columns: 3650
# Sparsity: 4.055%
# 610 3650

# %% [markdown]
# **Q5**. In order to fit a [LightFM](https://lyst.github.io/lightfm/docs/home.html) model, we need to transform our Dataframe to a sparse matrix (cf. below). This is not straightforward so we included the function `df_to_matrix` in `utils.py`.
#
# > 🔦 **Hint**:  Sparse matrices are just **big matrices with a lot of zeros or empty values**.
# >
# > Existing tools (Pandas DataFrame, Numpy arrays for example) are not suitable for manipulating this kind of data. So we will use [Scipy sparse matrices](https://docs.scipy.org/doc/scipy-0.14.0/reference/sparse.html).
# >
# > It exists many different "types" of sparse matrices (CSC, CSR, COO, DIA, etc.). You don't need to know them. Just know that it corresponds to different formats with different methods of manipulation, slicing, indexing, etc.
#
# > 🔦 **Hint 2**:  By going from a DataFrame to a sparse matrix, you will lose the information of the ids (userId and movieId), you will only deal with indices (row number and column number). Therefore, the `df_to_matrix` function also returns dictionaries mapping indexes to ids (ex: uid_to_idx mapping userId to index of the matrix)
#
#
# Have a look at the util function documentation, and use it to create 5 new variables:
# - a final sparse matrix `ratings_matrix` (this will be the data used to train the model)
# - the following utils mappers:
#     - `uid_to_idx`
#     - `idx_to_uid`
#     - `mid_to_idx`
#     - `idx_to_mid`

# %%
from utils import df_to_matrix
 
ratings_matrix, uid_to_idx, idx_to_uid, mid_to_idx, idx_to_mid = df_to_matrix(ratings_thresh_df, 'userId', 'movieId')
ratings_matrix
# Out:
# <610x3650 sparse matrix of type '<class 'numpy.float64'>'
# 	with 90274 stored elements in Compressed Sparse Row format>

# %% [markdown]
# **Q6**.
# - On the one side, find what movies did the userId 4 rate?
#
# - On the other side, what is the value of `ratings_matrix` for:
#     - userId = 4 and movieId=1
#     - userId = 4 and movieId=2
#     - userId = 4 and movieId=21
#     - userId = 4 and movieId=32
#     - userId = 4 and movieId=126
#
# Conclude on the values signification in `ratings_matrix`

# %%
ratings[ratings.userId==4]
# Out:
#      userId  movieId  rating   timestamp
# 300       4       21     3.0   986935199
# 301       4       32     2.0   945173447
# 302       4       45     3.0   986935047
# 303       4       47     2.0   945173425
# 304       4       52     3.0   964622786
# ..      ...      ...     ...         ...
# 511       4     4765     5.0  1007569445
# 512       4     4881     3.0  1007569445
# 513       4     4896     4.0  1007574532
# 514       4     4902     4.0  1007569465
# 515       4     4967     5.0  1007569424
#
# [216 rows x 4 columns]

# %%
for mid in [1, 2, 21, 32, 126]:
    print("For MID", mid)
    print("Matrix value (for userId 4) is ", ratings_matrix[uid_to_idx[4], mid_to_idx[mid]])
# Out:
# For MID 1
# Matrix value (for userId 4) is  0.0
# For MID 2
# Matrix value (for userId 4) is  0.0
# For MID 21
# Matrix value (for userId 4) is  1.0
# For MID 32
# Matrix value (for userId 4) is  1.0
# For MID 126
# Matrix value (for userId 4) is  1.0

# %% [markdown]
# **Q5**. Now that you have a `ratings_matrix` in the correct format, let's save it in pickle format:
# - Create a variable `dst_dir` corresponding to the path of the folder `data/netflix` located at the root of the repository
# - **Verify that this is the correct path**
# - Save the ratings_matrix in pickle (as `ratings_matrix.pkl`) in this corresponding directory

# %%
directory = "./data"
import pickle

# %%
pickle.dump(ratings_matrix, open(directory + "/ratings_matrix.pkl", "wb"))

# %% [markdown]
# **Q6**. Save also all mappings objects into pickle (`idx_to_mid`, `mid_to_idx`, `uid_to_idx`, `idx_to_uid`) as it will be useful for later.

# %%
#pickle.dump(idx_to_mid, open(directory + "/idx_to_mid.pkl", "wb")) 
#pickle.dump(mid_to_idx, open(directory + "/mid_to_idx.pkl", "wb")) 
#pickle.dump(uid_to_idx, open(directory + "/uid_to_idx.pkl", "wb")) 
pickle.dump(idx_to_uid, open(directory + "/idx_to_uid.pkl", "wb"))

# %%
pickle.dump(movies, open(directory + "/movies.pkl", "wb"))

# %% [markdown]
# Up to next challenge now! 🍿
